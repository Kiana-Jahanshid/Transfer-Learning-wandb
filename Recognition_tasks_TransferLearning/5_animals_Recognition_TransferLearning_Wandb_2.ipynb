# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wandb

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
import wandb

# %%
dataset_path = "/content/drive/MyDrive/5Animals"

# %%
width = height = 299
img_data_generator = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255 ,
    validation_split=0.1,
)
train_data= img_data_generator.flow_from_directory(
    dataset_path ,
    shuffle=True,
    subset="training",
    target_size=(width,height),
    batch_size=32
)

validation_data = img_data_generator.flow_from_directory(
    dataset_path,
    shuffle=True,
    subset="validation",
    target_size=(width,height),
    batch_size=32
)
# Out:
# Found 1171 images belonging to 5 classes.
# Found 128 images belonging to 5 classes.

# %% [markdown]
# ## train_data is an iterator , so :

# %%
next(train_data)[0].shape
# Out:
# (32, 299, 299, 3)

# %%
train_images = next(train_data)[0]
for i in range(16):
  plt.subplot(4,4,i+1)
  plt.imshow(train_images[i])

# %% [markdown]
# ## TransferLearning : weights="imagenet"

# %%
initial_model = tf.keras.applications.InceptionResNetV2(weights="imagenet" , input_shape=(width,height,3))
initial_model.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_609 (Conv2D)         (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_609 (B  (None, 149, 149, 32)         96        ['conv2d_609[0][0]']
#  atchNormalization)
#
#  activation_609 (Activation  (None, 149, 149, 32)         0         ['batch_normalization_609[0][0
#  )                                                                  ]']
#
#  conv2d_610 (Conv2D)         (None, 147, 147, 32)         9216      ['activation_609[0][0]']
#
#  batch_normalization_610 (B  (None, 147, 147, 32)         96        ['conv2d_610[0][0]']
#  atchNormalization)
#
#  activation_610 (Activation  (None, 147, 147, 32)         0         ['batch_normalization_610[0][0
#  )                                                                  ]']
#
#  conv2d_611 (Conv2D)         (None, 147, 147, 64)         18432     ['activation_610[0][0]']
#
#  batch_normalization_611 (B  (None, 147, 147, 64)         192       ['conv2d_611[0][0]']
#  atchNormalization)
#
#  activation_611 (Activation  (None, 147, 147, 64)         0         ['batch_normalization_611[0][0
#  )                                                                  ]']
#
#  max_pooling2d_12 (MaxPooli  (None, 73, 73, 64)           0         ['activation_611[0][0]']
#  ng2D)
#
#  conv2d_612 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_612 (B  (None, 73, 73, 80)           240       ['conv2d_612[0][0]']
#  atchNormalization)
#
#  activation_612 (Activation  (None, 73, 73, 80)           0         ['batch_normalization_612[0][0
#  )                                                                  ]']
#
#  conv2d_613 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_612[0][0]']
#
#  batch_normalization_613 (B  (None, 71, 71, 192)          576       ['conv2d_613[0][0]']
#  atchNormalization)
#
#  activation_613 (Activation  (None, 71, 71, 192)          0         ['batch_normalization_613[0][0
#  )                                                                  ]']
#
#  max_pooling2d_13 (MaxPooli  (None, 35, 35, 192)          0         ['activation_613[0][0]']
#  ng2D)
#
#  conv2d_617 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_617 (B  (None, 35, 35, 64)           192       ['conv2d_617[0][0]']
#  atchNormalization)
#
#  activation_617 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_617[0][0
#  )                                                                  ]']
#
#  conv2d_615 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_13[0][0]']
#
#  conv2d_618 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_617[0][0]']
#
#  batch_normalization_615 (B  (None, 35, 35, 48)           144       ['conv2d_615[0][0]']
#  atchNormalization)
#
#  batch_normalization_618 (B  (None, 35, 35, 96)           288       ['conv2d_618[0][0]']
#  atchNormalization)
#
#  activation_615 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_615[0][0
#  )                                                                  ]']
#
#  activation_618 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_618[0][0
#  )                                                                  ]']
#
#  average_pooling2d_3 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_13[0][0]']
#  gePooling2D)
#
#  conv2d_614 (Conv2D)         (None, 35, 35, 96)           18432     ['max_pooling2d_13[0][0]']
#
#  conv2d_616 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_615[0][0]']
#
#  conv2d_619 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_618[0][0]']
#
#  conv2d_620 (Conv2D)         (None, 35, 35, 64)           12288     ['average_pooling2d_3[0][0]']
#
#  batch_normalization_614 (B  (None, 35, 35, 96)           288       ['conv2d_614[0][0]']
#  atchNormalization)
#
#  batch_normalization_616 (B  (None, 35, 35, 64)           192       ['conv2d_616[0][0]']
#  atchNormalization)
#
#  batch_normalization_619 (B  (None, 35, 35, 96)           288       ['conv2d_619[0][0]']
#  atchNormalization)
#
#  batch_normalization_620 (B  (None, 35, 35, 64)           192       ['conv2d_620[0][0]']
#  atchNormalization)
#
#  activation_614 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_614[0][0
#  )                                                                  ]']
#
#  activation_616 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_616[0][0
#  )                                                                  ]']
#
#  activation_619 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_619[0][0
#  )                                                                  ]']
#
#  activation_620 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_620[0][0
#  )                                                                  ]']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_614[0][0]',
#                                                                      'activation_616[0][0]',
#                                                                      'activation_619[0][0]',
#                                                                      'activation_620[0][0]']
#
#  conv2d_624 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_624 (B  (None, 35, 35, 32)           96        ['conv2d_624[0][0]']
#  atchNormalization)
#
#  activation_624 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_624[0][0
#  )                                                                  ]']
#
#  conv2d_622 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_625 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_624[0][0]']
#
#  batch_normalization_622 (B  (None, 35, 35, 32)           96        ['conv2d_622[0][0]']
#  atchNormalization)
#
#  batch_normalization_625 (B  (None, 35, 35, 48)           144       ['conv2d_625[0][0]']
#  atchNormalization)
#
#  activation_622 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_622[0][0
#  )                                                                  ]']
#
#  activation_625 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_625[0][0
#  )                                                                  ]']
#
#  conv2d_621 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_623 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_622[0][0]']
#
#  conv2d_626 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_625[0][0]']
#
#  batch_normalization_621 (B  (None, 35, 35, 32)           96        ['conv2d_621[0][0]']
#  atchNormalization)
#
#  batch_normalization_623 (B  (None, 35, 35, 32)           96        ['conv2d_623[0][0]']
#  atchNormalization)
#
#  batch_normalization_626 (B  (None, 35, 35, 64)           192       ['conv2d_626[0][0]']
#  atchNormalization)
#
#  activation_621 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_621[0][0
#  )                                                                  ]']
#
#  activation_623 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_623[0][0
#  )                                                                  ]']
#
#  activation_626 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_626[0][0
#  )                                                                  ]']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_621[0][0]',
#  te)                                                                 'activation_623[0][0]',
#                                                                      'activation_626[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_120 (Cu  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  stomScaleLayer)                                                     'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_120[0][0]
#                                                                     ']
#
#  conv2d_630 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_630 (B  (None, 35, 35, 32)           96        ['conv2d_630[0][0]']
#  atchNormalization)
#
#  activation_630 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_630[0][0
#  )                                                                  ]']
#
#  conv2d_628 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_631 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_630[0][0]']
#
#  batch_normalization_628 (B  (None, 35, 35, 32)           96        ['conv2d_628[0][0]']
#  atchNormalization)
#
#  batch_normalization_631 (B  (None, 35, 35, 48)           144       ['conv2d_631[0][0]']
#  atchNormalization)
#
#  activation_628 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_628[0][0
#  )                                                                  ]']
#
#  activation_631 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_631[0][0
#  )                                                                  ]']
#
#  conv2d_627 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_629 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_628[0][0]']
#
#  conv2d_632 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_631[0][0]']
#
#  batch_normalization_627 (B  (None, 35, 35, 32)           96        ['conv2d_627[0][0]']
#  atchNormalization)
#
#  batch_normalization_629 (B  (None, 35, 35, 32)           96        ['conv2d_629[0][0]']
#  atchNormalization)
#
#  batch_normalization_632 (B  (None, 35, 35, 64)           192       ['conv2d_632[0][0]']
#  atchNormalization)
#
#  activation_627 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_627[0][0
#  )                                                                  ]']
#
#  activation_629 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_629[0][0
#  )                                                                  ]']
#
#  activation_632 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_632[0][0
#  )                                                                  ]']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_627[0][0]',
#  te)                                                                 'activation_629[0][0]',
#                                                                      'activation_632[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_121 (Cu  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  stomScaleLayer)                                                     'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_121[0][0]
#                                                                     ']
#
#  conv2d_636 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_636 (B  (None, 35, 35, 32)           96        ['conv2d_636[0][0]']
#  atchNormalization)
#
#  activation_636 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_636[0][0
#  )                                                                  ]']
#
#  conv2d_634 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_637 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_636[0][0]']
#
#  batch_normalization_634 (B  (None, 35, 35, 32)           96        ['conv2d_634[0][0]']
#  atchNormalization)
#
#  batch_normalization_637 (B  (None, 35, 35, 48)           144       ['conv2d_637[0][0]']
#  atchNormalization)
#
#  activation_634 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_634[0][0
#  )                                                                  ]']
#
#  activation_637 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_637[0][0
#  )                                                                  ]']
#
#  conv2d_633 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_635 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_634[0][0]']
#
#  conv2d_638 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_637[0][0]']
#
#  batch_normalization_633 (B  (None, 35, 35, 32)           96        ['conv2d_633[0][0]']
#  atchNormalization)
#
#  batch_normalization_635 (B  (None, 35, 35, 32)           96        ['conv2d_635[0][0]']
#  atchNormalization)
#
#  batch_normalization_638 (B  (None, 35, 35, 64)           192       ['conv2d_638[0][0]']
#  atchNormalization)
#
#  activation_633 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_633[0][0
#  )                                                                  ]']
#
#  activation_635 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_635[0][0
#  )                                                                  ]']
#
#  activation_638 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_638[0][0
#  )                                                                  ]']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_633[0][0]',
#  te)                                                                 'activation_635[0][0]',
#                                                                      'activation_638[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_122 (Cu  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  stomScaleLayer)                                                     'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_122[0][0]
#                                                                     ']
#
#  conv2d_642 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_642 (B  (None, 35, 35, 32)           96        ['conv2d_642[0][0]']
#  atchNormalization)
#
#  activation_642 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_642[0][0
#  )                                                                  ]']
#
#  conv2d_640 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_643 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_642[0][0]']
#
#  batch_normalization_640 (B  (None, 35, 35, 32)           96        ['conv2d_640[0][0]']
#  atchNormalization)
#
#  batch_normalization_643 (B  (None, 35, 35, 48)           144       ['conv2d_643[0][0]']
#  atchNormalization)
#
#  activation_640 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_640[0][0
#  )                                                                  ]']
#
#  activation_643 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_643[0][0
#  )                                                                  ]']
#
#  conv2d_639 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_641 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_640[0][0]']
#
#  conv2d_644 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_643[0][0]']
#
#  batch_normalization_639 (B  (None, 35, 35, 32)           96        ['conv2d_639[0][0]']
#  atchNormalization)
#
#  batch_normalization_641 (B  (None, 35, 35, 32)           96        ['conv2d_641[0][0]']
#  atchNormalization)
#
#  batch_normalization_644 (B  (None, 35, 35, 64)           192       ['conv2d_644[0][0]']
#  atchNormalization)
#
#  activation_639 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_639[0][0
#  )                                                                  ]']
#
#  activation_641 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_641[0][0
#  )                                                                  ]']
#
#  activation_644 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_644[0][0
#  )                                                                  ]']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_639[0][0]',
#  te)                                                                 'activation_641[0][0]',
#                                                                      'activation_644[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_123 (Cu  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  stomScaleLayer)                                                     'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_123[0][0]
#                                                                     ']
#
#  conv2d_648 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_648 (B  (None, 35, 35, 32)           96        ['conv2d_648[0][0]']
#  atchNormalization)
#
#  activation_648 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_648[0][0
#  )                                                                  ]']
#
#  conv2d_646 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_649 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_648[0][0]']
#
#  batch_normalization_646 (B  (None, 35, 35, 32)           96        ['conv2d_646[0][0]']
#  atchNormalization)
#
#  batch_normalization_649 (B  (None, 35, 35, 48)           144       ['conv2d_649[0][0]']
#  atchNormalization)
#
#  activation_646 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_646[0][0
#  )                                                                  ]']
#
#  activation_649 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_649[0][0
#  )                                                                  ]']
#
#  conv2d_645 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_647 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_646[0][0]']
#
#  conv2d_650 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_649[0][0]']
#
#  batch_normalization_645 (B  (None, 35, 35, 32)           96        ['conv2d_645[0][0]']
#  atchNormalization)
#
#  batch_normalization_647 (B  (None, 35, 35, 32)           96        ['conv2d_647[0][0]']
#  atchNormalization)
#
#  batch_normalization_650 (B  (None, 35, 35, 64)           192       ['conv2d_650[0][0]']
#  atchNormalization)
#
#  activation_645 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_645[0][0
#  )                                                                  ]']
#
#  activation_647 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_647[0][0
#  )                                                                  ]']
#
#  activation_650 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_650[0][0
#  )                                                                  ]']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_645[0][0]',
#  te)                                                                 'activation_647[0][0]',
#                                                                      'activation_650[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_124 (Cu  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  stomScaleLayer)                                                     'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_124[0][0]
#                                                                     ']
#
#  conv2d_654 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_654 (B  (None, 35, 35, 32)           96        ['conv2d_654[0][0]']
#  atchNormalization)
#
#  activation_654 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_654[0][0
#  )                                                                  ]']
#
#  conv2d_652 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_655 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_654[0][0]']
#
#  batch_normalization_652 (B  (None, 35, 35, 32)           96        ['conv2d_652[0][0]']
#  atchNormalization)
#
#  batch_normalization_655 (B  (None, 35, 35, 48)           144       ['conv2d_655[0][0]']
#  atchNormalization)
#
#  activation_652 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_652[0][0
#  )                                                                  ]']
#
#  activation_655 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_655[0][0
#  )                                                                  ]']
#
#  conv2d_651 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_653 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_652[0][0]']
#
#  conv2d_656 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_655[0][0]']
#
#  batch_normalization_651 (B  (None, 35, 35, 32)           96        ['conv2d_651[0][0]']
#  atchNormalization)
#
#  batch_normalization_653 (B  (None, 35, 35, 32)           96        ['conv2d_653[0][0]']
#  atchNormalization)
#
#  batch_normalization_656 (B  (None, 35, 35, 64)           192       ['conv2d_656[0][0]']
#  atchNormalization)
#
#  activation_651 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_651[0][0
#  )                                                                  ]']
#
#  activation_653 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_653[0][0
#  )                                                                  ]']
#
#  activation_656 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_656[0][0
#  )                                                                  ]']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_651[0][0]',
#  te)                                                                 'activation_653[0][0]',
#                                                                      'activation_656[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_125 (Cu  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  stomScaleLayer)                                                     'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_125[0][0]
#                                                                     ']
#
#  conv2d_660 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_660 (B  (None, 35, 35, 32)           96        ['conv2d_660[0][0]']
#  atchNormalization)
#
#  activation_660 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_660[0][0
#  )                                                                  ]']
#
#  conv2d_658 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
# ...
#  atchNormalization)
#
#  activation_796 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_796[0][0
#  )                                                                  ]']
#
#  activation_799 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_799[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_796[0][0]',
#  e)                                                                  'activation_799[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_156 (Cu  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  stomScaleLayer)                                                     'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_156[0][0]
#                                                                     ']
#
#  conv2d_801 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_801 (B  (None, 8, 8, 192)            576       ['conv2d_801[0][0]']
#  atchNormalization)
#
#  activation_801 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_801[0][0
#  )                                                                  ]']
#
#  conv2d_802 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_801[0][0]']
#
#  batch_normalization_802 (B  (None, 8, 8, 224)            672       ['conv2d_802[0][0]']
#  atchNormalization)
#
#  activation_802 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_802[0][0
#  )                                                                  ]']
#
#  conv2d_800 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_803 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_802[0][0]']
#
#  batch_normalization_800 (B  (None, 8, 8, 192)            576       ['conv2d_800[0][0]']
#  atchNormalization)
#
#  batch_normalization_803 (B  (None, 8, 8, 256)            768       ['conv2d_803[0][0]']
#  atchNormalization)
#
#  activation_800 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_800[0][0
#  )                                                                  ]']
#
#  activation_803 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_803[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_800[0][0]',
#  e)                                                                  'activation_803[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_157 (Cu  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  stomScaleLayer)                                                     'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_157[0][0]
#                                                                     ']
#
#  conv2d_805 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_805 (B  (None, 8, 8, 192)            576       ['conv2d_805[0][0]']
#  atchNormalization)
#
#  activation_805 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_805[0][0
#  )                                                                  ]']
#
#  conv2d_806 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_805[0][0]']
#
#  batch_normalization_806 (B  (None, 8, 8, 224)            672       ['conv2d_806[0][0]']
#  atchNormalization)
#
#  activation_806 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_806[0][0
#  )                                                                  ]']
#
#  conv2d_804 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_807 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_806[0][0]']
#
#  batch_normalization_804 (B  (None, 8, 8, 192)            576       ['conv2d_804[0][0]']
#  atchNormalization)
#
#  batch_normalization_807 (B  (None, 8, 8, 256)            768       ['conv2d_807[0][0]']
#  atchNormalization)
#
#  activation_804 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_804[0][0
#  )                                                                  ]']
#
#  activation_807 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_807[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_804[0][0]',
#  e)                                                                  'activation_807[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_158 (Cu  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  stomScaleLayer)                                                     'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_158[0][0]
#                                                                     ']
#
#  conv2d_809 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_809 (B  (None, 8, 8, 192)            576       ['conv2d_809[0][0]']
#  atchNormalization)
#
#  activation_809 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_809[0][0
#  )                                                                  ]']
#
#  conv2d_810 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_809[0][0]']
#
#  batch_normalization_810 (B  (None, 8, 8, 224)            672       ['conv2d_810[0][0]']
#  atchNormalization)
#
#  activation_810 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_810[0][0
#  )                                                                  ]']
#
#  conv2d_808 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_811 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_810[0][0]']
#
#  batch_normalization_808 (B  (None, 8, 8, 192)            576       ['conv2d_808[0][0]']
#  atchNormalization)
#
#  batch_normalization_811 (B  (None, 8, 8, 256)            768       ['conv2d_811[0][0]']
#  atchNormalization)
#
#  activation_808 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_808[0][0
#  )                                                                  ]']
#
#  activation_811 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_811[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_808[0][0]',
#  te)                                                                 'activation_811[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_159 (Cu  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  stomScaleLayer)                                                     'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_159[0][0]
#                                                                     ']
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 1537000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 55873736 (213.14 MB)
# Trainable params: 55813192 (212.91 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## include_top = False :

# %% [markdown]
#  ## these 2 layers have been deleted :
#  ### because of include_top=False
#  avg_pool (GlobalAveragePoo(None,1536))
#  predictions (Dense)(None, 1000)

# %%
initial_model = tf.keras.applications.InceptionResNetV2(weights="imagenet" , include_top=False , input_shape=(width,height,3))
initial_model.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_812 (Conv2D)         (None, 149, 149, 32)         864       ['input_5[0][0]']
#
#  batch_normalization_812 (B  (None, 149, 149, 32)         96        ['conv2d_812[0][0]']
#  atchNormalization)
#
#  activation_812 (Activation  (None, 149, 149, 32)         0         ['batch_normalization_812[0][0
#  )                                                                  ]']
#
#  conv2d_813 (Conv2D)         (None, 147, 147, 32)         9216      ['activation_812[0][0]']
#
#  batch_normalization_813 (B  (None, 147, 147, 32)         96        ['conv2d_813[0][0]']
#  atchNormalization)
#
#  activation_813 (Activation  (None, 147, 147, 32)         0         ['batch_normalization_813[0][0
#  )                                                                  ]']
#
#  conv2d_814 (Conv2D)         (None, 147, 147, 64)         18432     ['activation_813[0][0]']
#
#  batch_normalization_814 (B  (None, 147, 147, 64)         192       ['conv2d_814[0][0]']
#  atchNormalization)
#
#  activation_814 (Activation  (None, 147, 147, 64)         0         ['batch_normalization_814[0][0
#  )                                                                  ]']
#
#  max_pooling2d_16 (MaxPooli  (None, 73, 73, 64)           0         ['activation_814[0][0]']
#  ng2D)
#
#  conv2d_815 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_815 (B  (None, 73, 73, 80)           240       ['conv2d_815[0][0]']
#  atchNormalization)
#
#  activation_815 (Activation  (None, 73, 73, 80)           0         ['batch_normalization_815[0][0
#  )                                                                  ]']
#
#  conv2d_816 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_815[0][0]']
#
#  batch_normalization_816 (B  (None, 71, 71, 192)          576       ['conv2d_816[0][0]']
#  atchNormalization)
#
#  activation_816 (Activation  (None, 71, 71, 192)          0         ['batch_normalization_816[0][0
#  )                                                                  ]']
#
#  max_pooling2d_17 (MaxPooli  (None, 35, 35, 192)          0         ['activation_816[0][0]']
#  ng2D)
#
#  conv2d_820 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_820 (B  (None, 35, 35, 64)           192       ['conv2d_820[0][0]']
#  atchNormalization)
#
#  activation_820 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_820[0][0
#  )                                                                  ]']
#
#  conv2d_818 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_17[0][0]']
#
#  conv2d_821 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_820[0][0]']
#
#  batch_normalization_818 (B  (None, 35, 35, 48)           144       ['conv2d_818[0][0]']
#  atchNormalization)
#
#  batch_normalization_821 (B  (None, 35, 35, 96)           288       ['conv2d_821[0][0]']
#  atchNormalization)
#
#  activation_818 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_818[0][0
#  )                                                                  ]']
#
#  activation_821 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_821[0][0
#  )                                                                  ]']
#
#  average_pooling2d_4 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_17[0][0]']
#  gePooling2D)
#
#  conv2d_817 (Conv2D)         (None, 35, 35, 96)           18432     ['max_pooling2d_17[0][0]']
#
#  conv2d_819 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_818[0][0]']
#
#  conv2d_822 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_821[0][0]']
#
#  conv2d_823 (Conv2D)         (None, 35, 35, 64)           12288     ['average_pooling2d_4[0][0]']
#
#  batch_normalization_817 (B  (None, 35, 35, 96)           288       ['conv2d_817[0][0]']
#  atchNormalization)
#
#  batch_normalization_819 (B  (None, 35, 35, 64)           192       ['conv2d_819[0][0]']
#  atchNormalization)
#
#  batch_normalization_822 (B  (None, 35, 35, 96)           288       ['conv2d_822[0][0]']
#  atchNormalization)
#
#  batch_normalization_823 (B  (None, 35, 35, 64)           192       ['conv2d_823[0][0]']
#  atchNormalization)
#
#  activation_817 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_817[0][0
#  )                                                                  ]']
#
#  activation_819 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_819[0][0
#  )                                                                  ]']
#
#  activation_822 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_822[0][0
#  )                                                                  ]']
#
#  activation_823 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_823[0][0
#  )                                                                  ]']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_817[0][0]',
#                                                                      'activation_819[0][0]',
#                                                                      'activation_822[0][0]',
#                                                                      'activation_823[0][0]']
#
#  conv2d_827 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_827 (B  (None, 35, 35, 32)           96        ['conv2d_827[0][0]']
#  atchNormalization)
#
#  activation_827 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_827[0][0
#  )                                                                  ]']
#
#  conv2d_825 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_828 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_827[0][0]']
#
#  batch_normalization_825 (B  (None, 35, 35, 32)           96        ['conv2d_825[0][0]']
#  atchNormalization)
#
#  batch_normalization_828 (B  (None, 35, 35, 48)           144       ['conv2d_828[0][0]']
#  atchNormalization)
#
#  activation_825 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_825[0][0
#  )                                                                  ]']
#
#  activation_828 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_828[0][0
#  )                                                                  ]']
#
#  conv2d_824 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_826 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_825[0][0]']
#
#  conv2d_829 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_828[0][0]']
#
#  batch_normalization_824 (B  (None, 35, 35, 32)           96        ['conv2d_824[0][0]']
#  atchNormalization)
#
#  batch_normalization_826 (B  (None, 35, 35, 32)           96        ['conv2d_826[0][0]']
#  atchNormalization)
#
#  batch_normalization_829 (B  (None, 35, 35, 64)           192       ['conv2d_829[0][0]']
#  atchNormalization)
#
#  activation_824 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_824[0][0
#  )                                                                  ]']
#
#  activation_826 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_826[0][0
#  )                                                                  ]']
#
#  activation_829 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_829[0][0
#  )                                                                  ]']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_824[0][0]',
#  te)                                                                 'activation_826[0][0]',
#                                                                      'activation_829[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_160 (Cu  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  stomScaleLayer)                                                     'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_160[0][0]
#                                                                     ']
#
#  conv2d_833 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_833 (B  (None, 35, 35, 32)           96        ['conv2d_833[0][0]']
#  atchNormalization)
#
#  activation_833 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_833[0][0
#  )                                                                  ]']
#
#  conv2d_831 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_834 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_833[0][0]']
#
#  batch_normalization_831 (B  (None, 35, 35, 32)           96        ['conv2d_831[0][0]']
#  atchNormalization)
#
#  batch_normalization_834 (B  (None, 35, 35, 48)           144       ['conv2d_834[0][0]']
#  atchNormalization)
#
#  activation_831 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_831[0][0
#  )                                                                  ]']
#
#  activation_834 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_834[0][0
#  )                                                                  ]']
#
#  conv2d_830 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_832 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_831[0][0]']
#
#  conv2d_835 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_834[0][0]']
#
#  batch_normalization_830 (B  (None, 35, 35, 32)           96        ['conv2d_830[0][0]']
#  atchNormalization)
#
#  batch_normalization_832 (B  (None, 35, 35, 32)           96        ['conv2d_832[0][0]']
#  atchNormalization)
#
#  batch_normalization_835 (B  (None, 35, 35, 64)           192       ['conv2d_835[0][0]']
#  atchNormalization)
#
#  activation_830 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_830[0][0
#  )                                                                  ]']
#
#  activation_832 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_832[0][0
#  )                                                                  ]']
#
#  activation_835 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_835[0][0
#  )                                                                  ]']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_830[0][0]',
#  te)                                                                 'activation_832[0][0]',
#                                                                      'activation_835[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_161 (Cu  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  stomScaleLayer)                                                     'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_161[0][0]
#                                                                     ']
#
#  conv2d_839 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_839 (B  (None, 35, 35, 32)           96        ['conv2d_839[0][0]']
#  atchNormalization)
#
#  activation_839 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_839[0][0
#  )                                                                  ]']
#
#  conv2d_837 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_840 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_839[0][0]']
#
#  batch_normalization_837 (B  (None, 35, 35, 32)           96        ['conv2d_837[0][0]']
#  atchNormalization)
#
#  batch_normalization_840 (B  (None, 35, 35, 48)           144       ['conv2d_840[0][0]']
#  atchNormalization)
#
#  activation_837 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_837[0][0
#  )                                                                  ]']
#
#  activation_840 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_840[0][0
#  )                                                                  ]']
#
#  conv2d_836 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_838 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_837[0][0]']
#
#  conv2d_841 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_840[0][0]']
#
#  batch_normalization_836 (B  (None, 35, 35, 32)           96        ['conv2d_836[0][0]']
#  atchNormalization)
#
#  batch_normalization_838 (B  (None, 35, 35, 32)           96        ['conv2d_838[0][0]']
#  atchNormalization)
#
#  batch_normalization_841 (B  (None, 35, 35, 64)           192       ['conv2d_841[0][0]']
#  atchNormalization)
#
#  activation_836 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_836[0][0
#  )                                                                  ]']
#
#  activation_838 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_838[0][0
#  )                                                                  ]']
#
#  activation_841 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_841[0][0
#  )                                                                  ]']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_836[0][0]',
#  te)                                                                 'activation_838[0][0]',
#                                                                      'activation_841[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_162 (Cu  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  stomScaleLayer)                                                     'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_162[0][0]
#                                                                     ']
#
#  conv2d_845 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_845 (B  (None, 35, 35, 32)           96        ['conv2d_845[0][0]']
#  atchNormalization)
#
#  activation_845 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_845[0][0
#  )                                                                  ]']
#
#  conv2d_843 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_846 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_845[0][0]']
#
#  batch_normalization_843 (B  (None, 35, 35, 32)           96        ['conv2d_843[0][0]']
#  atchNormalization)
#
#  batch_normalization_846 (B  (None, 35, 35, 48)           144       ['conv2d_846[0][0]']
#  atchNormalization)
#
#  activation_843 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_843[0][0
#  )                                                                  ]']
#
#  activation_846 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_846[0][0
#  )                                                                  ]']
#
#  conv2d_842 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_844 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_843[0][0]']
#
#  conv2d_847 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_846[0][0]']
#
#  batch_normalization_842 (B  (None, 35, 35, 32)           96        ['conv2d_842[0][0]']
#  atchNormalization)
#
#  batch_normalization_844 (B  (None, 35, 35, 32)           96        ['conv2d_844[0][0]']
#  atchNormalization)
#
#  batch_normalization_847 (B  (None, 35, 35, 64)           192       ['conv2d_847[0][0]']
#  atchNormalization)
#
#  activation_842 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_842[0][0
#  )                                                                  ]']
#
#  activation_844 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_844[0][0
#  )                                                                  ]']
#
#  activation_847 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_847[0][0
#  )                                                                  ]']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_842[0][0]',
#  te)                                                                 'activation_844[0][0]',
#                                                                      'activation_847[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_163 (Cu  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  stomScaleLayer)                                                     'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_163[0][0]
#                                                                     ']
#
#  conv2d_851 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_851 (B  (None, 35, 35, 32)           96        ['conv2d_851[0][0]']
#  atchNormalization)
#
#  activation_851 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_851[0][0
#  )                                                                  ]']
#
#  conv2d_849 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_852 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_851[0][0]']
#
#  batch_normalization_849 (B  (None, 35, 35, 32)           96        ['conv2d_849[0][0]']
#  atchNormalization)
#
#  batch_normalization_852 (B  (None, 35, 35, 48)           144       ['conv2d_852[0][0]']
#  atchNormalization)
#
#  activation_849 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_849[0][0
#  )                                                                  ]']
#
#  activation_852 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_852[0][0
#  )                                                                  ]']
#
#  conv2d_848 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_850 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_849[0][0]']
#
#  conv2d_853 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_852[0][0]']
#
#  batch_normalization_848 (B  (None, 35, 35, 32)           96        ['conv2d_848[0][0]']
#  atchNormalization)
#
#  batch_normalization_850 (B  (None, 35, 35, 32)           96        ['conv2d_850[0][0]']
#  atchNormalization)
#
#  batch_normalization_853 (B  (None, 35, 35, 64)           192       ['conv2d_853[0][0]']
#  atchNormalization)
#
#  activation_848 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_848[0][0
#  )                                                                  ]']
#
#  activation_850 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_850[0][0
#  )                                                                  ]']
#
#  activation_853 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_853[0][0
#  )                                                                  ]']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_848[0][0]',
#  te)                                                                 'activation_850[0][0]',
#                                                                      'activation_853[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_164 (Cu  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  stomScaleLayer)                                                     'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_164[0][0]
#                                                                     ']
#
#  conv2d_857 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_857 (B  (None, 35, 35, 32)           96        ['conv2d_857[0][0]']
#  atchNormalization)
#
#  activation_857 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_857[0][0
#  )                                                                  ]']
#
#  conv2d_855 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_858 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_857[0][0]']
#
#  batch_normalization_855 (B  (None, 35, 35, 32)           96        ['conv2d_855[0][0]']
#  atchNormalization)
#
#  batch_normalization_858 (B  (None, 35, 35, 48)           144       ['conv2d_858[0][0]']
#  atchNormalization)
#
#  activation_855 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_855[0][0
#  )                                                                  ]']
#
#  activation_858 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_858[0][0
#  )                                                                  ]']
#
#  conv2d_854 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_856 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_855[0][0]']
#
#  conv2d_859 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_858[0][0]']
#
#  batch_normalization_854 (B  (None, 35, 35, 32)           96        ['conv2d_854[0][0]']
#  atchNormalization)
#
#  batch_normalization_856 (B  (None, 35, 35, 32)           96        ['conv2d_856[0][0]']
#  atchNormalization)
#
#  batch_normalization_859 (B  (None, 35, 35, 64)           192       ['conv2d_859[0][0]']
#  atchNormalization)
#
#  activation_854 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_854[0][0
#  )                                                                  ]']
#
#  activation_856 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_856[0][0
#  )                                                                  ]']
#
#  activation_859 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_859[0][0
#  )                                                                  ]']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_854[0][0]',
#  te)                                                                 'activation_856[0][0]',
#                                                                      'activation_859[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_165 (Cu  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  stomScaleLayer)                                                     'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_165[0][0]
#                                                                     ']
#
#  conv2d_863 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_863 (B  (None, 35, 35, 32)           96        ['conv2d_863[0][0]']
#  atchNormalization)
#
#  activation_863 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_863[0][0
#  )                                                                  ]']
#
#  conv2d_861 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
# ...
#
#  batch_normalization_999 (B  (None, 8, 8, 192)            576       ['conv2d_999[0][0]']
#  atchNormalization)
#
#  batch_normalization_1002 (  (None, 8, 8, 256)            768       ['conv2d_1002[0][0]']
#  BatchNormalization)
#
#  activation_999 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_999[0][0
#  )                                                                  ]']
#
#  activation_1002 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1002[0][
#  n)                                                                 0]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_999[0][0]',
#  e)                                                                  'activation_1002[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_196 (Cu  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  stomScaleLayer)                                                     'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_196[0][0]
#                                                                     ']
#
#  conv2d_1004 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_1004 (  (None, 8, 8, 192)            576       ['conv2d_1004[0][0]']
#  BatchNormalization)
#
#  activation_1004 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1004[0][
#  n)                                                                 0]']
#
#  conv2d_1005 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1004[0][0]']
#
#  batch_normalization_1005 (  (None, 8, 8, 224)            672       ['conv2d_1005[0][0]']
#  BatchNormalization)
#
#  activation_1005 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1005[0][
#  n)                                                                 0]']
#
#  conv2d_1003 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_1006 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1005[0][0]']
#
#  batch_normalization_1003 (  (None, 8, 8, 192)            576       ['conv2d_1003[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1006 (  (None, 8, 8, 256)            768       ['conv2d_1006[0][0]']
#  BatchNormalization)
#
#  activation_1003 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1003[0][
#  n)                                                                 0]']
#
#  activation_1006 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1006[0][
#  n)                                                                 0]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_1003[0][0]',
#  e)                                                                  'activation_1006[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_197 (Cu  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  stomScaleLayer)                                                     'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_197[0][0]
#                                                                     ']
#
#  conv2d_1008 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_1008 (  (None, 8, 8, 192)            576       ['conv2d_1008[0][0]']
#  BatchNormalization)
#
#  activation_1008 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1008[0][
#  n)                                                                 0]']
#
#  conv2d_1009 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1008[0][0]']
#
#  batch_normalization_1009 (  (None, 8, 8, 224)            672       ['conv2d_1009[0][0]']
#  BatchNormalization)
#
#  activation_1009 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1009[0][
#  n)                                                                 0]']
#
#  conv2d_1007 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_1010 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1009[0][0]']
#
#  batch_normalization_1007 (  (None, 8, 8, 192)            576       ['conv2d_1007[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1010 (  (None, 8, 8, 256)            768       ['conv2d_1010[0][0]']
#  BatchNormalization)
#
#  activation_1007 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1007[0][
#  n)                                                                 0]']
#
#  activation_1010 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1010[0][
#  n)                                                                 0]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_1007[0][0]',
#  e)                                                                  'activation_1010[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_198 (Cu  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  stomScaleLayer)                                                     'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_198[0][0]
#                                                                     ']
#
#  conv2d_1012 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_1012 (  (None, 8, 8, 192)            576       ['conv2d_1012[0][0]']
#  BatchNormalization)
#
#  activation_1012 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1012[0][
#  n)                                                                 0]']
#
#  conv2d_1013 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1012[0][0]']
#
#  batch_normalization_1013 (  (None, 8, 8, 224)            672       ['conv2d_1013[0][0]']
#  BatchNormalization)
#
#  activation_1013 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1013[0][
#  n)                                                                 0]']
#
#  conv2d_1011 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_1014 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1013[0][0]']
#
#  batch_normalization_1011 (  (None, 8, 8, 192)            576       ['conv2d_1011[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1014 (  (None, 8, 8, 256)            768       ['conv2d_1014[0][0]']
#  BatchNormalization)
#
#  activation_1011 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1011[0][
#  n)                                                                 0]']
#
#  activation_1014 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1014[0][
#  n)                                                                 0]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_1011[0][0]',
#  te)                                                                 'activation_1014[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_199 (Cu  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  stomScaleLayer)                                                     'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_199[0][0]
#                                                                     ']
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54336736 (207.28 MB)
# Trainable params: 54276192 (207.05 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## حالا خودمون باید اون دوتا لایه رو بسازیم ::
# اما لایه پولینگ رو میتونیم اینجوری بسازیم ::
# اینجوری فقط لایه دنس را حذف کردیم

# %%
initial_model = tf.keras.applications.InceptionResNetV2(weights="imagenet",
                                                        include_top=False,
                                                        pooling="avg",
                                                        input_shape=(width,height,3))
initial_model.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_1015 (Conv2D)        (None, 149, 149, 32)         864       ['input_6[0][0]']
#
#  batch_normalization_1015 (  (None, 149, 149, 32)         96        ['conv2d_1015[0][0]']
#  BatchNormalization)
#
#  activation_1015 (Activatio  (None, 149, 149, 32)         0         ['batch_normalization_1015[0][
#  n)                                                                 0]']
#
#  conv2d_1016 (Conv2D)        (None, 147, 147, 32)         9216      ['activation_1015[0][0]']
#
#  batch_normalization_1016 (  (None, 147, 147, 32)         96        ['conv2d_1016[0][0]']
#  BatchNormalization)
#
#  activation_1016 (Activatio  (None, 147, 147, 32)         0         ['batch_normalization_1016[0][
#  n)                                                                 0]']
#
#  conv2d_1017 (Conv2D)        (None, 147, 147, 64)         18432     ['activation_1016[0][0]']
#
#  batch_normalization_1017 (  (None, 147, 147, 64)         192       ['conv2d_1017[0][0]']
#  BatchNormalization)
#
#  activation_1017 (Activatio  (None, 147, 147, 64)         0         ['batch_normalization_1017[0][
#  n)                                                                 0]']
#
#  max_pooling2d_20 (MaxPooli  (None, 73, 73, 64)           0         ['activation_1017[0][0]']
#  ng2D)
#
#  conv2d_1018 (Conv2D)        (None, 73, 73, 80)           5120      ['max_pooling2d_20[0][0]']
#
#  batch_normalization_1018 (  (None, 73, 73, 80)           240       ['conv2d_1018[0][0]']
#  BatchNormalization)
#
#  activation_1018 (Activatio  (None, 73, 73, 80)           0         ['batch_normalization_1018[0][
#  n)                                                                 0]']
#
#  conv2d_1019 (Conv2D)        (None, 71, 71, 192)          138240    ['activation_1018[0][0]']
#
#  batch_normalization_1019 (  (None, 71, 71, 192)          576       ['conv2d_1019[0][0]']
#  BatchNormalization)
#
#  activation_1019 (Activatio  (None, 71, 71, 192)          0         ['batch_normalization_1019[0][
#  n)                                                                 0]']
#
#  max_pooling2d_21 (MaxPooli  (None, 35, 35, 192)          0         ['activation_1019[0][0]']
#  ng2D)
#
#  conv2d_1023 (Conv2D)        (None, 35, 35, 64)           12288     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_1023 (  (None, 35, 35, 64)           192       ['conv2d_1023[0][0]']
#  BatchNormalization)
#
#  activation_1023 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1023[0][
#  n)                                                                 0]']
#
#  conv2d_1021 (Conv2D)        (None, 35, 35, 48)           9216      ['max_pooling2d_21[0][0]']
#
#  conv2d_1024 (Conv2D)        (None, 35, 35, 96)           55296     ['activation_1023[0][0]']
#
#  batch_normalization_1021 (  (None, 35, 35, 48)           144       ['conv2d_1021[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1024 (  (None, 35, 35, 96)           288       ['conv2d_1024[0][0]']
#  BatchNormalization)
#
#  activation_1021 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1021[0][
#  n)                                                                 0]']
#
#  activation_1024 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1024[0][
#  n)                                                                 0]']
#
#  average_pooling2d_5 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_21[0][0]']
#  gePooling2D)
#
#  conv2d_1020 (Conv2D)        (None, 35, 35, 96)           18432     ['max_pooling2d_21[0][0]']
#
#  conv2d_1022 (Conv2D)        (None, 35, 35, 64)           76800     ['activation_1021[0][0]']
#
#  conv2d_1025 (Conv2D)        (None, 35, 35, 96)           82944     ['activation_1024[0][0]']
#
#  conv2d_1026 (Conv2D)        (None, 35, 35, 64)           12288     ['average_pooling2d_5[0][0]']
#
#  batch_normalization_1020 (  (None, 35, 35, 96)           288       ['conv2d_1020[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1022 (  (None, 35, 35, 64)           192       ['conv2d_1022[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1025 (  (None, 35, 35, 96)           288       ['conv2d_1025[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1026 (  (None, 35, 35, 64)           192       ['conv2d_1026[0][0]']
#  BatchNormalization)
#
#  activation_1020 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1020[0][
#  n)                                                                 0]']
#
#  activation_1022 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1022[0][
#  n)                                                                 0]']
#
#  activation_1025 (Activatio  (None, 35, 35, 96)           0         ['batch_normalization_1025[0][
#  n)                                                                 0]']
#
#  activation_1026 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1026[0][
#  n)                                                                 0]']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_1020[0][0]',
#                                                                      'activation_1022[0][0]',
#                                                                      'activation_1025[0][0]',
#                                                                      'activation_1026[0][0]']
#
#  conv2d_1030 (Conv2D)        (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_1030 (  (None, 35, 35, 32)           96        ['conv2d_1030[0][0]']
#  BatchNormalization)
#
#  activation_1030 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1030[0][
#  n)                                                                 0]']
#
#  conv2d_1028 (Conv2D)        (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_1031 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1030[0][0]']
#
#  batch_normalization_1028 (  (None, 35, 35, 32)           96        ['conv2d_1028[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1031 (  (None, 35, 35, 48)           144       ['conv2d_1031[0][0]']
#  BatchNormalization)
#
#  activation_1028 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1028[0][
#  n)                                                                 0]']
#
#  activation_1031 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1031[0][
#  n)                                                                 0]']
#
#  conv2d_1027 (Conv2D)        (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_1029 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1028[0][0]']
#
#  conv2d_1032 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1031[0][0]']
#
#  batch_normalization_1027 (  (None, 35, 35, 32)           96        ['conv2d_1027[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1029 (  (None, 35, 35, 32)           96        ['conv2d_1029[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1032 (  (None, 35, 35, 64)           192       ['conv2d_1032[0][0]']
#  BatchNormalization)
#
#  activation_1027 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1027[0][
#  n)                                                                 0]']
#
#  activation_1029 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1029[0][
#  n)                                                                 0]']
#
#  activation_1032 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1032[0][
#  n)                                                                 0]']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1027[0][0]',
#  te)                                                                 'activation_1029[0][0]',
#                                                                      'activation_1032[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_200 (Cu  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  stomScaleLayer)                                                     'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_200[0][0]
#                                                                     ']
#
#  conv2d_1036 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_1036 (  (None, 35, 35, 32)           96        ['conv2d_1036[0][0]']
#  BatchNormalization)
#
#  activation_1036 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1036[0][
#  n)                                                                 0]']
#
#  conv2d_1034 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_1037 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1036[0][0]']
#
#  batch_normalization_1034 (  (None, 35, 35, 32)           96        ['conv2d_1034[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1037 (  (None, 35, 35, 48)           144       ['conv2d_1037[0][0]']
#  BatchNormalization)
#
#  activation_1034 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1034[0][
#  n)                                                                 0]']
#
#  activation_1037 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1037[0][
#  n)                                                                 0]']
#
#  conv2d_1033 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_1035 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1034[0][0]']
#
#  conv2d_1038 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1037[0][0]']
#
#  batch_normalization_1033 (  (None, 35, 35, 32)           96        ['conv2d_1033[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1035 (  (None, 35, 35, 32)           96        ['conv2d_1035[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1038 (  (None, 35, 35, 64)           192       ['conv2d_1038[0][0]']
#  BatchNormalization)
#
#  activation_1033 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1033[0][
#  n)                                                                 0]']
#
#  activation_1035 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1035[0][
#  n)                                                                 0]']
#
#  activation_1038 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1038[0][
#  n)                                                                 0]']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1033[0][0]',
#  te)                                                                 'activation_1035[0][0]',
#                                                                      'activation_1038[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_201 (Cu  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  stomScaleLayer)                                                     'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_201[0][0]
#                                                                     ']
#
#  conv2d_1042 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_1042 (  (None, 35, 35, 32)           96        ['conv2d_1042[0][0]']
#  BatchNormalization)
#
#  activation_1042 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1042[0][
#  n)                                                                 0]']
#
#  conv2d_1040 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_1043 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1042[0][0]']
#
#  batch_normalization_1040 (  (None, 35, 35, 32)           96        ['conv2d_1040[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1043 (  (None, 35, 35, 48)           144       ['conv2d_1043[0][0]']
#  BatchNormalization)
#
#  activation_1040 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1040[0][
#  n)                                                                 0]']
#
#  activation_1043 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1043[0][
#  n)                                                                 0]']
#
#  conv2d_1039 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_1041 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1040[0][0]']
#
#  conv2d_1044 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1043[0][0]']
#
#  batch_normalization_1039 (  (None, 35, 35, 32)           96        ['conv2d_1039[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1041 (  (None, 35, 35, 32)           96        ['conv2d_1041[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1044 (  (None, 35, 35, 64)           192       ['conv2d_1044[0][0]']
#  BatchNormalization)
#
#  activation_1039 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1039[0][
#  n)                                                                 0]']
#
#  activation_1041 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1041[0][
#  n)                                                                 0]']
#
#  activation_1044 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1044[0][
#  n)                                                                 0]']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1039[0][0]',
#  te)                                                                 'activation_1041[0][0]',
#                                                                      'activation_1044[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_202 (Cu  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  stomScaleLayer)                                                     'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_202[0][0]
#                                                                     ']
#
#  conv2d_1048 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_1048 (  (None, 35, 35, 32)           96        ['conv2d_1048[0][0]']
#  BatchNormalization)
#
#  activation_1048 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1048[0][
#  n)                                                                 0]']
#
#  conv2d_1046 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_1049 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1048[0][0]']
#
#  batch_normalization_1046 (  (None, 35, 35, 32)           96        ['conv2d_1046[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1049 (  (None, 35, 35, 48)           144       ['conv2d_1049[0][0]']
#  BatchNormalization)
#
#  activation_1046 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1046[0][
#  n)                                                                 0]']
#
#  activation_1049 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1049[0][
#  n)                                                                 0]']
#
#  conv2d_1045 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_1047 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1046[0][0]']
#
#  conv2d_1050 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1049[0][0]']
#
#  batch_normalization_1045 (  (None, 35, 35, 32)           96        ['conv2d_1045[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1047 (  (None, 35, 35, 32)           96        ['conv2d_1047[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1050 (  (None, 35, 35, 64)           192       ['conv2d_1050[0][0]']
#  BatchNormalization)
#
#  activation_1045 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1045[0][
#  n)                                                                 0]']
#
#  activation_1047 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1047[0][
#  n)                                                                 0]']
#
#  activation_1050 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1050[0][
#  n)                                                                 0]']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1045[0][0]',
#  te)                                                                 'activation_1047[0][0]',
#                                                                      'activation_1050[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_203 (Cu  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  stomScaleLayer)                                                     'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_203[0][0]
#                                                                     ']
#
#  conv2d_1054 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_1054 (  (None, 35, 35, 32)           96        ['conv2d_1054[0][0]']
#  BatchNormalization)
#
#  activation_1054 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1054[0][
#  n)                                                                 0]']
#
#  conv2d_1052 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_1055 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1054[0][0]']
#
#  batch_normalization_1052 (  (None, 35, 35, 32)           96        ['conv2d_1052[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1055 (  (None, 35, 35, 48)           144       ['conv2d_1055[0][0]']
#  BatchNormalization)
#
#  activation_1052 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1052[0][
#  n)                                                                 0]']
#
#  activation_1055 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1055[0][
#  n)                                                                 0]']
#
#  conv2d_1051 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_1053 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1052[0][0]']
#
#  conv2d_1056 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1055[0][0]']
#
#  batch_normalization_1051 (  (None, 35, 35, 32)           96        ['conv2d_1051[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1053 (  (None, 35, 35, 32)           96        ['conv2d_1053[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1056 (  (None, 35, 35, 64)           192       ['conv2d_1056[0][0]']
#  BatchNormalization)
#
#  activation_1051 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1051[0][
#  n)                                                                 0]']
#
#  activation_1053 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1053[0][
#  n)                                                                 0]']
#
#  activation_1056 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1056[0][
#  n)                                                                 0]']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1051[0][0]',
#  te)                                                                 'activation_1053[0][0]',
#                                                                      'activation_1056[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_204 (Cu  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  stomScaleLayer)                                                     'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_204[0][0]
#                                                                     ']
#
#  conv2d_1060 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_1060 (  (None, 35, 35, 32)           96        ['conv2d_1060[0][0]']
#  BatchNormalization)
#
#  activation_1060 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1060[0][
#  n)                                                                 0]']
#
#  conv2d_1058 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_1061 (Conv2D)        (None, 35, 35, 48)           13824     ['activation_1060[0][0]']
#
#  batch_normalization_1058 (  (None, 35, 35, 32)           96        ['conv2d_1058[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1061 (  (None, 35, 35, 48)           144       ['conv2d_1061[0][0]']
#  BatchNormalization)
#
#  activation_1058 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1058[0][
#  n)                                                                 0]']
#
#  activation_1061 (Activatio  (None, 35, 35, 48)           0         ['batch_normalization_1061[0][
#  n)                                                                 0]']
#
#  conv2d_1057 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_1059 (Conv2D)        (None, 35, 35, 32)           9216      ['activation_1058[0][0]']
#
#  conv2d_1062 (Conv2D)        (None, 35, 35, 64)           27648     ['activation_1061[0][0]']
#
#  batch_normalization_1057 (  (None, 35, 35, 32)           96        ['conv2d_1057[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1059 (  (None, 35, 35, 32)           96        ['conv2d_1059[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1062 (  (None, 35, 35, 64)           192       ['conv2d_1062[0][0]']
#  BatchNormalization)
#
#  activation_1057 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1057[0][
#  n)                                                                 0]']
#
#  activation_1059 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1059[0][
#  n)                                                                 0]']
#
#  activation_1062 (Activatio  (None, 35, 35, 64)           0         ['batch_normalization_1062[0][
#  n)                                                                 0]']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_1057[0][0]',
#  te)                                                                 'activation_1059[0][0]',
#                                                                      'activation_1062[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_205 (Cu  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  stomScaleLayer)                                                     'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_205[0][0]
#                                                                     ']
#
#  conv2d_1066 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_1066 (  (None, 35, 35, 32)           96        ['conv2d_1066[0][0]']
#  BatchNormalization)
#
#  activation_1066 (Activatio  (None, 35, 35, 32)           0         ['batch_normalization_1066[0][
#  n)                                                                 0]']
#
#  conv2d_1064 (Conv2D)        (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
# ...
#
#  batch_normalization_1205 (  (None, 8, 8, 256)            768       ['conv2d_1205[0][0]']
#  BatchNormalization)
#
#  activation_1202 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1202[0][
#  n)                                                                 0]']
#
#  activation_1205 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1205[0][
#  n)                                                                 0]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_1202[0][0]',
#  e)                                                                  'activation_1205[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_236 (Cu  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  stomScaleLayer)                                                     'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_236[0][0]
#                                                                     ']
#
#  conv2d_1207 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_1207 (  (None, 8, 8, 192)            576       ['conv2d_1207[0][0]']
#  BatchNormalization)
#
#  activation_1207 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1207[0][
#  n)                                                                 0]']
#
#  conv2d_1208 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1207[0][0]']
#
#  batch_normalization_1208 (  (None, 8, 8, 224)            672       ['conv2d_1208[0][0]']
#  BatchNormalization)
#
#  activation_1208 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1208[0][
#  n)                                                                 0]']
#
#  conv2d_1206 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_1209 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1208[0][0]']
#
#  batch_normalization_1206 (  (None, 8, 8, 192)            576       ['conv2d_1206[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1209 (  (None, 8, 8, 256)            768       ['conv2d_1209[0][0]']
#  BatchNormalization)
#
#  activation_1206 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1206[0][
#  n)                                                                 0]']
#
#  activation_1209 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1209[0][
#  n)                                                                 0]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_1206[0][0]',
#  e)                                                                  'activation_1209[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_237 (Cu  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  stomScaleLayer)                                                     'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_237[0][0]
#                                                                     ']
#
#  conv2d_1211 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_1211 (  (None, 8, 8, 192)            576       ['conv2d_1211[0][0]']
#  BatchNormalization)
#
#  activation_1211 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1211[0][
#  n)                                                                 0]']
#
#  conv2d_1212 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1211[0][0]']
#
#  batch_normalization_1212 (  (None, 8, 8, 224)            672       ['conv2d_1212[0][0]']
#  BatchNormalization)
#
#  activation_1212 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1212[0][
#  n)                                                                 0]']
#
#  conv2d_1210 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_1213 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1212[0][0]']
#
#  batch_normalization_1210 (  (None, 8, 8, 192)            576       ['conv2d_1210[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1213 (  (None, 8, 8, 256)            768       ['conv2d_1213[0][0]']
#  BatchNormalization)
#
#  activation_1210 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1210[0][
#  n)                                                                 0]']
#
#  activation_1213 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1213[0][
#  n)                                                                 0]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_1210[0][0]',
#  e)                                                                  'activation_1213[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_238 (Cu  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  stomScaleLayer)                                                     'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_238[0][0]
#                                                                     ']
#
#  conv2d_1215 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_1215 (  (None, 8, 8, 192)            576       ['conv2d_1215[0][0]']
#  BatchNormalization)
#
#  activation_1215 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1215[0][
#  n)                                                                 0]']
#
#  conv2d_1216 (Conv2D)        (None, 8, 8, 224)            129024    ['activation_1215[0][0]']
#
#  batch_normalization_1216 (  (None, 8, 8, 224)            672       ['conv2d_1216[0][0]']
#  BatchNormalization)
#
#  activation_1216 (Activatio  (None, 8, 8, 224)            0         ['batch_normalization_1216[0][
#  n)                                                                 0]']
#
#  conv2d_1214 (Conv2D)        (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_1217 (Conv2D)        (None, 8, 8, 256)            172032    ['activation_1216[0][0]']
#
#  batch_normalization_1214 (  (None, 8, 8, 192)            576       ['conv2d_1214[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1217 (  (None, 8, 8, 256)            768       ['conv2d_1217[0][0]']
#  BatchNormalization)
#
#  activation_1214 (Activatio  (None, 8, 8, 192)            0         ['batch_normalization_1214[0][
#  n)                                                                 0]']
#
#  activation_1217 (Activatio  (None, 8, 8, 256)            0         ['batch_normalization_1217[0][
#  n)                                                                 0]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_1214[0][0]',
#  te)                                                                 'activation_1217[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_239 (Cu  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  stomScaleLayer)                                                     'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_239[0][0]
#                                                                     ']
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#   (GlobalAveragePooling2D)
#
# ==================================================================================================
# Total params: 54336736 (207.28 MB)
# Trainable params: 54276192 (207.05 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # FREEZING SOME LAYERS :
#
# نمیخوایم همه ی لایه ها ترین بشن

# %% [markdown]
# ## اگر بخوایم چهار لایه آخر شبکه فریز نشوند  :
# چهارتای آخر را درنظر نمیگیریم
# یعنی میخوایم ۴ لایه آخر شبکه ترین بشوند ولی بقیه نه

# %%
for layer in initial_model.layers[:-4]:
 layer.trainable=False

#initial_model.summary()

# %%
model = tf.keras.models.Sequential([
    initial_model,
    tf.keras.layers.Dropout(0.2), # 0.2 is probability that a neuron will be inactive and 80% active
    tf.keras.layers.Dense(5 , activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Funct  (None, 1536)              54336736
#  ional)
#
#  dropout_1 (Dropout)         (None, 1536)              0
#
#  dense_1 (Dense)             (None, 5)                 7685
#
# =================================================================
# Total params: 54344421 (207.31 MB)
# Trainable params: 54283877 (207.08 MB)
# Non-trainable params: 60544 (236.50 KB)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001) ,
              loss=tf.keras.losses.categorical_crossentropy ,
              metrics=["accuracy"] )

# %%
run = wandb.init(project="5-animals")
# Out:
# Finishing last run (ID:qki89smx) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='6374.530 MB of 6374.530 MB uploaded (20.918 MB deduped)\r'), FloatProgress(value=1…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>▁▇▇▇▇███████████████████████████████████</td></tr><tr><td>batch/batch_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>batch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>█▃▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/accuracy</td><td>▁▆████▇█▇█</td></tr><tr><td>epoch/epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▃▂▁▁▁▂▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▇█▇▇▇▇██▇</td></tr><tr><td>epoch/val_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>0.99385</td></tr><tr><td>batch/batch_step</td><td>395</td></tr><tr><td>batch/learning_rate</td><td>0.001</td></tr><tr><td>batch/loss</td><td>0.01238</td></tr><tr><td>epoch/accuracy</td><td>0.99402</td></tr><tr><td>epoch/epoch</td><td>9</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.01221</td></tr><tr><td>epoch/val_accuracy</td><td>0.96094</td></tr><tr><td>epoch/val_loss</td><td>0.13576</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misunderstood-darkness-2</strong> at: <a href='https://wandb.ai/kianajahanshid/5-animals/runs/qki89smx' target="_blank">https://wandb.ai/kianajahanshid/5-animals/runs/qki89smx</a><br/>Synced 5 W&B file(s), 0 media file(s), 50 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231027_190716-qki89smx/logs</code>
# Successfully finished last run (ID:qki89smx). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231027_194816-cobnjtay</code>
# Syncing run <strong><a href='https://wandb.ai/kianajahanshid/5-animals/runs/cobnjtay' target="_blank">ethereal-rain-3</a></strong> to <a href='https://wandb.ai/kianajahanshid/5-animals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kianajahanshid/5-animals' target="_blank">https://wandb.ai/kianajahanshid/5-animals</a>
#  View run at <a href='https://wandb.ai/kianajahanshid/5-animals/runs/cobnjtay' target="_blank">https://wandb.ai/kianajahanshid/5-animals/runs/cobnjtay</a>

# %%
from wandb.sdk.wandb_run import wandb_metric
config = wandb.config
from wandb.keras import (
   WandbMetricsLogger,
   WandbModelCheckpoint,
)

wandb_callbacks = [
   WandbMetricsLogger(log_freq=5),
   WandbModelCheckpoint("models"),
]

# %%
history = model.fit(train_data , validation_data=validation_data , epochs=10 , callbacks=wandb_callbacks)
# Out:
# Epoch 1/10
# 37/37 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8915
# wandb: Adding directory to artifact (./models)... Done. 9.6s
# 37/37 [==============================] - 232s 4s/step - loss: 0.3375 - accuracy: 0.8915 - val_loss: 19.1140 - val_accuracy: 0.6484
# Epoch 2/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9675
# wandb: Adding directory to artifact (./models)... Done. 3.5s
# 37/37 [==============================] - 157s 4s/step - loss: 0.0858 - accuracy: 0.9675 - val_loss: 0.4024 - val_accuracy: 0.9375
# Epoch 3/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9812
# wandb: Adding directory to artifact (./models)... Done. 3.5s
# 37/37 [==============================] - 155s 4s/step - loss: 0.0551 - accuracy: 0.9812 - val_loss: 0.1333 - val_accuracy: 0.9844
# Epoch 4/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9906
# wandb: Adding directory to artifact (./models)... Done. 6.8s
# 37/37 [==============================] - 161s 4s/step - loss: 0.0325 - accuracy: 0.9906 - val_loss: 0.1403 - val_accuracy: 0.9766
# Epoch 5/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9940
# wandb: Adding directory to artifact (./models)... Done. 3.6s
# 37/37 [==============================] - 153s 4s/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0946 - val_accuracy: 0.9766
# Epoch 6/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9966
# wandb: Adding directory to artifact (./models)... Done. 3.6s
# 37/37 [==============================] - 156s 4s/step - loss: 0.0175 - accuracy: 0.9966 - val_loss: 0.0941 - val_accuracy: 0.9609
# Epoch 7/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9923
# wandb: Adding directory to artifact (./models)... Done. 7.5s
# 37/37 [==============================] - 161s 4s/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 0.0937 - val_accuracy: 0.9766
# Epoch 8/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9983
# wandb: Adding directory to artifact (./models)... Done. 3.5s
# 37/37 [==============================] - 156s 4s/step - loss: 0.0092 - accuracy: 0.9983 - val_loss: 0.0534 - val_accuracy: 0.9844
# Epoch 9/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9991
# wandb: Adding directory to artifact (./models)... Done. 3.5s
# 37/37 [==============================] - 153s 4s/step - loss: 0.0057 - accuracy: 0.9991 - val_loss: 0.0340 - val_accuracy: 0.9844
# Epoch 10/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9991
# wandb: Adding directory to artifact (./models)... Done. 3.5s
# 37/37 [==============================] - 153s 4s/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0122 - val_accuracy: 1.0000

# %% [markdown]
# | Layers Freezed|without Dropout| with Droput = 0.2 |with Droput = 0.5 |
# | ------------- | :-------------: | :-------------: |:-------------: |
# | validation Accuracy  | 0.9766  | 0.9922  | 0.9766  |

# %% [markdown]
# |without Freezing layers|without Dropout| with Droput = 0.2 | with Droput = 0.5 |
# | ------------- | :-------------: | :-------------: | :-------------: |
# | validation Accuracy  | 1.0000  | 0.9609  | 1.0000  |

# %%
#model.save("/content/drive/MyDrive/5animals_weights.keras")

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["loss"], label='Train')
plt.plot(history.history["val_accuracy"], label='Validation')
plt.plot(history.history["val_loss"])
plt.legend(["accuracy","loss" , "val_accuracy" , "val_loss"])
plt.xlabel("Epochs")
plt.ylabel("loss & accuracy")
plt.show()

# %%
#y_pred = model.predict(validation_data)
#y_predlist = np.array(list(y_pred))
#print(y_predlist[5])
#print(np.argmax(y_predlist[5]))
#ypred_list = []
#for i in range(len(y_predlist)):
#  ypred_list.append(np.argmax(y_predlist[i]))

#print(ypred_list)

# %%
images,labels = validation_data[1]
ypred_list = []
for image in images:
    image = np.expand_dims(image, axis=0)
    ypred=model.predict(image)
    ypred_list.append(np.argmax(ypred))
ytrue_list = []
for label in labels:
    ytrue_list.append(np.argmax(label))

# %%
np.array(ytrue_list)
# Out:
# array([2, 4, 3, 4, 3, 4, 2, 0, 0, 4, 1, 4, 4, 3, 4, 1, 0, 3, 4, 2, 1, 4,
#        1, 1, 0, 0, 4, 2, 3, 0, 0, 0])

# %%
np.array(ypred_list)
# Out:
# array([2, 4, 3, 4, 3, 4, 2, 0, 0, 4, 1, 4, 4, 3, 4, 1, 0, 3, 4, 2, 1, 4,
#        1, 1, 0, 0, 4, 2, 3, 0, 0, 0])

# %%
confm = metrics.confusion_matrix(y_true= ytrue_list , y_pred= ypred_list  )
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confm , display_labels=['cat','dog','elephant','giraffe','panda'])
cm_display.plot(cmap=plt.cm.Oranges , xticks_rotation="vertical")
plt.show()

# %% [markdown]
# # Inference

# %%
#model= tf.keras.models.load_model("/content/drive/MyDrive/5animals_weights.keras")

# %% [markdown]
# شبکه همیشه تصاویر را به صورت بچ میخواد از ما . یعنی ورودی شبکه همیشه ۴ بعدی است .
# یکی از این ۴ تا بعد بچ سایز است
# اما حالا که فقط میخوایم یک تصویر بدیم بازم باید تصویر رو ۴ بعدی بکنیم

# %%
import cv2

new_image = cv2.imread("/content/c3.jpg")
new_image = cv2.cvtColor(new_image , cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
new_image = cv2.resize(new_image , (299,299))
new_image = new_image / 255.0
new_image = np.reshape(new_image, [1, 299, 299, 3]) # new_iamge.reshape(1,299,299,3)

output = model.predict(new_image)

predicted_class = np.argmax(output)
print(predicted_class)
print(train_data.class_indices)
mylist = list(train_data.class_indices)
print("predicted label : " , mylist[np.argmax(output)])
# Out:
# 1/1 [==============================] - 4s 4s/step
# 0
# {'cat': 0, 'dog': 1, 'elephant': 2, 'giraffe': 3, 'panda': 4}
# predicted label :  cat

# %%
new_image = cv2.imread("/content/dog2.jpg")
new_image = cv2.cvtColor(new_image , cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
new_image = cv2.resize(new_image , (299,299))
new_image = new_image / 255.0
new_image = np.reshape(new_image, [1, 299, 299, 3]) # new_iamge.reshape(1,299,299,3)

output = model.predict(new_image)

predicted_class = np.argmax(output)
print(predicted_class)
print(train_data.class_indices)
mylist = list(train_data.class_indices)
print("predicted label : " , mylist[np.argmax(output)])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1
# {'cat': 0, 'dog': 1, 'elephant': 2, 'giraffe': 3, 'panda': 4}
# predicted label :  dog

# %%
new_image = cv2.imread("/content/ele1.jpg")
new_image = cv2.cvtColor(new_image , cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
new_image = cv2.resize(new_image , (299,299))
new_image = new_image / 255.0
new_image = np.reshape(new_image, [1, 299, 299, 3]) # new_iamge.reshape(1,299,299,3)

output = model.predict(new_image)

predicted_class = np.argmax(output)
print(predicted_class)
print(train_data.class_indices)
mylist = list(train_data.class_indices)
print("predicted label : " , mylist[np.argmax(output)])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 2
# {'cat': 0, 'dog': 1, 'elephant': 2, 'giraffe': 3, 'panda': 4}
# predicted label :  elephant

# %%
new_image = cv2.imread("/content/pan.jpg")
new_image = cv2.cvtColor(new_image , cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
new_image = cv2.resize(new_image , (299,299))
new_image = new_image / 255.0
new_image = np.reshape(new_image, [1, 299, 299, 3]) # new_iamge.reshape(1,299,299,3)

output = model.predict(new_image)

predicted_class = np.argmax(output)
print(predicted_class)
print(train_data.class_indices)
mylist = list(train_data.class_indices)
print("predicted label : " , mylist[np.argmax(output)])
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 4
# {'cat': 0, 'dog': 1, 'elephant': 2, 'giraffe': 3, 'panda': 4}
# predicted label :  panda
